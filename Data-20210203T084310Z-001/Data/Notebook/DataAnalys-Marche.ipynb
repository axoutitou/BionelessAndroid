# %%
import pandas as pd

# %%
filename = "MouvementData-V1-Marche.csv"
data = pd.read_csv(filename, delimiter=",")
data.shape
# Out:
# (1157, 8)

# %%
data.head()
# Out:
#      dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr    dZ-gyr   time  \
# 0 -1.477267  9.644139 -0.962499  0.000000  0.000000  0.000000  315.0
# 1 -1.477267  9.644139 -0.962499 -0.000143  0.022212 -0.029041  316.0
# 2 -1.477267  9.644139 -0.962499  0.034066 -0.015662 -0.077910  495.0
# 3 -1.477267  9.644139 -0.962499  0.034066 -0.015662 -0.077910  513.0
# 4 -1.477267  9.644139 -0.962499  0.034066 -0.015662 -0.077910  514.0
#
#   activityType
# 0      Marcher
# 1      Marcher
# 2      Marcher
# 3      Marcher
# 4      Marcher

# %%
data.tail()
# Out:
#         dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr   dZ-gyr     time  \
# 1152 -4.187587  8.466156 -0.442941 -0.071003  0.057642 -0.12067  21123.0
# 1153 -4.319272  8.509253 -0.962499 -0.071003  0.057642 -0.12067  21124.0
# 1154 -4.671230  8.612206 -0.641666 -0.071003  0.057642 -0.12067  21125.0
# 1155 -4.826858  8.432636 -0.347170 -0.071003  0.057642 -0.12067  21126.0
# 1156 -4.862772  8.514041 -0.141262 -0.071003  0.057642 -0.12067  21127.0
#
#      activityType
# 1152      Marcher
# 1153      Marcher
# 1154      Marcher
# 1155      Marcher
# 1156      Marcher

# %%
data.tail()
# Out:
#         dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr   dZ-gyr     time  \
# 1152 -4.187587  8.466156 -0.442941 -0.071003  0.057642 -0.12067  21123.0
# 1153 -4.319272  8.509253 -0.962499 -0.071003  0.057642 -0.12067  21124.0
# 1154 -4.671230  8.612206 -0.641666 -0.071003  0.057642 -0.12067  21125.0
# 1155 -4.826858  8.432636 -0.347170 -0.071003  0.057642 -0.12067  21126.0
# 1156 -4.862772  8.514041 -0.141262 -0.071003  0.057642 -0.12067  21127.0
#
#      activityType
# 1152      Marcher
# 1153      Marcher
# 1154      Marcher
# 1155      Marcher
# 1156      Marcher

# %%
time_inf = 5800
time_sup = 12000
data = data.loc[(data['time']>time_inf) & (data['time']<time_sup)]

# %%
data.head()
# Out:
#        dX-acc     dY-acc    dZ-acc   dX-gyr    dY-gyr    dZ-gyr    time  \
# 302 -1.242629  11.379988 -2.856370 -0.17485 -0.571549 -1.613625  5896.0
# 303 -0.299284  12.553183 -2.672011 -0.17485 -0.571549 -1.613625  5918.0
# 304  2.032739  11.454210 -2.145270 -0.17485 -0.571549 -1.613625  5919.0
# 305  2.219493  10.826911 -1.371919 -0.17485 -0.571549 -1.613625  5921.0
# 306  1.901054  10.970567 -1.137281 -0.17485 -0.571549 -1.613625  5922.0
#
#     activityType
# 302      Marcher
# 303      Marcher
# 304      Marcher
# 305      Marcher
# 306      Marcher

# %%
data.tail()
# Out:
#        dX-acc     dY-acc    dZ-acc    dX-gyr    dY-gyr    dZ-gyr     time  \
# 641 -6.366377  14.451842  1.379102  0.150741 -1.001599  0.445602  11921.0
# 642 -2.767782   9.306546  1.764581  0.150741 -1.001599  0.445602  11922.0
# 643 -0.469278   7.247470 -0.634483  0.150741 -1.001599  0.445602  11923.0
# 644  0.967287   7.762239 -3.763800  0.150741 -1.001599  0.445602  11924.0
# 645  0.234639   8.145323 -4.632922  0.150741 -1.001599  0.445602  11926.0
#
#     activityType
# 641      Marcher
# 642      Marcher
# 643      Marcher
# 644      Marcher
# 645      Marcher

# %% [markdown]
# Timer :
# - 6.03
# - 7.58
# - 9.02
# - 10.55
# - 11.6

# %%
def addTimerLine(axs):
    timer = [6030, 7580, 9020, 10550, 11600]
    for i in range(len(timer)) :
        for y in range(3) :
            axs[y].axvline(x=timer[i], color='red')

# %% [markdown]
# ## Accelerometer visualisation

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(3)
fig.set_size_inches(20, 13)
axs[0].plot(data["time"], data["dX-acc"])
axs[1].plot(data["time"], data["dY-acc"])
axs[2].plot(data["time"], data["dZ-acc"])

addTimerLine(axs)

# %% [markdown]
# ## Gyroscope visualisation

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(3)
fig.set_size_inches(20, 13)
axs[0].plot(data["time"], data["dX-gyr"])
axs[1].plot(data["time"], data["dY-gyr"])
axs[2].plot(data["time"], data["dZ-gyr"])

addTimerLine(axs)
