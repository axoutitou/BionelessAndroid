# %%
import pandas as pd

# %%
filename = "MouvementData-V1-Course.csv"
data = pd.read_csv(filename, delimiter=",")
data.shape
# Out:
# (559, 8)

# %%
data.head()
# Out:
#      dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr    dZ-gyr   time  \
# 0  0.000000  0.000000  0.000000  0.009631  0.027709 -0.019878  320.0
# 1 -2.126116  9.402317 -0.885882  0.009631  0.027709 -0.019878  340.0
# 2 -2.126116  9.402317 -0.885882  0.009631  0.027709 -0.019878  340.0
# 3 -2.126116  9.402317 -0.885882  0.009631  0.020990  0.036322  500.0
# 4 -2.126116  9.402317 -0.885882  0.009631  0.020990  0.036322  542.0
#
#   activityType
# 0       Courir
# 1       Courir
# 2       Courir
# 3       Courir
# 4       Courir

# %%
data.tail()
# Out:
#        dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr    dZ-gyr     time  \
# 554 -1.953728  9.352037 -1.261783 -0.001365 -0.001612 -0.030873  10367.0
# 555 -1.927391  9.457385 -1.177983 -0.001365 -0.001612 -0.030873  10368.0
# 556 -1.865140  9.548367 -1.376708 -0.001365 -0.001612 -0.030873  10369.0
# 557 -1.896266  9.490906 -1.122915 -0.001365 -0.001612 -0.030873  10370.0
# 558 -1.963305  9.419077 -1.204320 -0.001365 -0.001612 -0.030873  10371.0
#
#     activityType
# 554       Courir
# 555       Courir
# 556       Courir
# 557       Courir
# 558       Courir

# %%
data.tail()
# Out:
#        dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr    dZ-gyr     time  \
# 554 -1.953728  9.352037 -1.261783 -0.001365 -0.001612 -0.030873  10367.0
# 555 -1.927391  9.457385 -1.177983 -0.001365 -0.001612 -0.030873  10368.0
# 556 -1.865140  9.548367 -1.376708 -0.001365 -0.001612 -0.030873  10369.0
# 557 -1.896266  9.490906 -1.122915 -0.001365 -0.001612 -0.030873  10370.0
# 558 -1.963305  9.419077 -1.204320 -0.001365 -0.001612 -0.030873  10371.0
#
#     activityType
# 554       Courir
# 555       Courir
# 556       Courir
# 557       Courir
# 558       Courir

# %%
time_inf = 1500
time_sup = 4800
data = data.loc[(data['time']>time_inf) & (data['time']<time_sup)]

# %%
data.head()
# Out:
#       dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr    dZ-gyr    time  \
# 59 -2.013585  9.464568 -1.240234 -0.011749  0.036262 -0.025375  1545.0
# 60 -1.824437  9.399923 -1.283331 -0.011749  0.036262 -0.025375  1546.0
# 61 -1.817254  9.438231 -1.297697 -0.011749  0.036262 -0.025375  1547.0
# 62 -1.673598  9.502876 -1.154041 -0.011749  0.036262 -0.025375  1548.0
# 63 -1.822043  9.517242 -1.146858 -0.011749  0.036262 -0.025375  1550.0
#
#    activityType
# 59       Courir
# 60       Courir
# 61       Courir
# 62       Courir
# 63       Courir

# %%
data.tail()
# Out:
#        dX-acc    dY-acc    dZ-acc    dX-gyr    dY-gyr    dZ-gyr    time  \
# 242 -1.582616  9.567522 -1.230657 -0.002586  0.001442 -0.046756  4750.0
# 243 -1.652050  9.538791 -1.103761 -0.002586  0.001442 -0.046756  4751.0
# 244 -1.640078  9.498088 -1.098972 -0.002586  0.001442 -0.046756  4752.0
# 245 -1.491633  9.500483 -1.144463 -0.002586  0.001442 -0.046756  4753.0
# 246 -1.458113  9.550762 -1.338400 -0.002586  0.001442 -0.046756  4754.0
#
#     activityType
# 242       Courir
# 243       Courir
# 244       Courir
# 245       Courir
# 246       Courir

# %% [markdown]
# Timer :
# - 1.81
# - 2.54
# - 3.29
# - 3.98
# - 4.61

# %%
def addTimerLine(axs):
    timer = [1810, 2540, 3290, 3980, 4610]
    for i in range(len(timer)) :
        for y in range(3) :
            axs[y].axvline(x=timer[i], color='red')

# %% [markdown]
# ## Accelerometer visualisation

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(3)
fig.set_size_inches(20, 13)
axs[0].plot(data["time"], data["dX-acc"])
axs[1].plot(data["time"], data["dY-acc"])
axs[2].plot(data["time"], data["dZ-acc"])

addTimerLine(axs)

# %% [markdown]
# ## Gyroscope visualisation

# %%
import matplotlib.pyplot as plt
fig, axs = plt.subplots(3)
fig.set_size_inches(20, 13)
axs[0].plot(data["time"], data["dX-gyr"])
axs[1].plot(data["time"], data["dY-gyr"])
axs[2].plot(data["time"], data["dZ-gyr"])

addTimerLine(axs)
